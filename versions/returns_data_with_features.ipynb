# %% [markdown]
# This file analyizes data from the 6/24/25 SQL query provided by Mary May on full feature set in features.md with the exclusion of product<>trend features

# %%
import pandas as pd

# %%
df = pd.read_csv('basic_metrics_return_behavior_temporal_features_trend_features_e_202506241544.csv')

# %%
print(f"Loaded {df.shape[0]:,} rows and {df.shape[1]:,} columns.")
# Show summary statistics and missing values
display_cols = [col for col in df.columns if df[col].dtype != 'O']
print("Summary statistics:")
display(df[display_cols].describe().T.round(2))
print("\nMissing values per column:")
display(df.isnull().sum())
print("\nFirst 5 rows:")
display(df.head())
# Out:
# Loaded 15,000 rows and 47 columns.
# Summary statistics:
#                                       count     mean       std    min     25%  \
# SALES_ORDER_NO_NUNIQUE              15000.0    55.70    100.30  11.00   17.00
# SKU_NUNIQUE                         15000.0   123.79    228.24   1.00   34.00
# ITEMS_RETURNED_COUNT                15000.0  7045.37  77535.63   0.00   72.00
# SALES_QTY_MEAN                      15000.0     1.17      2.72   1.00    1.02
# AVG_ORDER_SIZE                      15000.0     2.45      1.30   1.00    1.64
# RETURN_RATE                         15000.0     0.22      0.18   0.00    0.08
# RETURN_RATIO                        15000.0     0.21      0.17   0.00    0.07
# RETURN_PRODUCT_VARIETY              15000.0    31.84     81.12   0.00    4.00
# AVG_RETURNS_PER_ORDER               15000.0    93.96    430.06   0.00    7.00
# RETURN_FREQUENCY_RATIO              15000.0    40.45     91.98   0.00    5.58
# ...
